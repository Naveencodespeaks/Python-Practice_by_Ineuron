# %%
import pandas as pd

# %%
df = pd.read_excel(r'C:\Users\SVKUSER\Downloads\Attribute DataSet.xlxs.xlsx')

# %%
df
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.read_excel(r'C:\Users\SVKUSER\Downloads\Attribute DataSet.xlxs.xlsx' , sheet_name = "naveen")
# Out:
#    Average    5     M  Summer     o-neck
# 0  Average  5.0  free  Summer     o-neck
# 1      Low  4.6  free  Spring     v-neck
# 2  Average  4.5     M  Summer     o-neck
# 3  Average  4.5     L  Spring  boat-neck
# 4  Average  4.5  free  Autumn     o-neck
# 5      Low  0.0     M  Summer  boat-neck
# 6  Average  4.9     M  winter     o-neck

# %%
pd.read_excel(r'C:\Users\SVKUSER\Downloads\Attribute DataSet.xlxs.xlsx' , sheet_name = "Adep")
# Out:
#    Average  4.9     M  winter          o-neck  halfsleeve     null    cotton  \
# 0  Average  4.8     M  Summer          o-neck  halfsleeve      NaN       NaN
# 1      Low  4.4     L  Summer          o-neck   sleevless  natural    cotton
# 2  Average  4.3     M  winter      slash-neck  sleeveless  natural  polyster
# 3  Average  4.7     L  Summer          o-neck   sleevless  natural  polyster
# 4  Average  0.0     S  Summer          v-neck   sleevless      NaN       NaN
# 5      Low  4.4  free  Summer          o-neck   sleevless      NaN       NaN
# 6     high  4.3     M  Spring       boat-neck        full  natural  polyster
# 7  Average  4.8     M  winter  turndowncollor        full  natural       NaN
#
#        null.1
# 0         NaN
# 1     chiffon
# 2         NaN
# 3  broadcloth
# 4         NaN
# 5         NaN
# 6       terry
# 7         NaN

# %%
pd.read_excel(r'C:\Users\SVKUSER\Downloads\Attribute DataSet.xlxs.xlsx' , sheet_name = "Adep",header=None)
# Out:
#          0    1     2       3               4           5        6         7  \
# 0  Average  4.9     M  winter          o-neck  halfsleeve      NaN    cotton
# 1  Average  4.8     M  Summer          o-neck  halfsleeve      NaN       NaN
# 2      Low  4.4     L  Summer          o-neck   sleevless  natural    cotton
# 3  Average  4.3     M  winter      slash-neck  sleeveless  natural  polyster
# 4  Average  4.7     L  Summer          o-neck   sleevless  natural  polyster
# 5  Average  0.0     S  Summer          v-neck   sleevless      NaN       NaN
# 6      Low  4.4  free  Summer          o-neck   sleevless      NaN       NaN
# 7     high  4.3     M  Spring       boat-neck        full  natural  polyster
# 8  Average  4.8     M  winter  turndowncollor        full  natural       NaN
#
#             8
# 0         NaN
# 1         NaN
# 2     chiffon
# 3         NaN
# 4  broadcloth
# 5         NaN
# 6         NaN
# 7       terry
# 8         NaN

# %%
pd.read_excel(r'C:\Users\SVKUSER\Downloads\Attribute DataSet.xlxs.xlsx' , sheet_name = "Adep",header=None, names=['A','b',"c","D","e","f","g","h","i"])
# Out:
#          A    b     c       D               e           f        g         h  \
# 0  Average  4.9     M  winter          o-neck  halfsleeve      NaN    cotton
# 1  Average  4.8     M  Summer          o-neck  halfsleeve      NaN       NaN
# 2      Low  4.4     L  Summer          o-neck   sleevless  natural    cotton
# 3  Average  4.3     M  winter      slash-neck  sleeveless  natural  polyster
# 4  Average  4.7     L  Summer          o-neck   sleevless  natural  polyster
# 5  Average  0.0     S  Summer          v-neck   sleevless      NaN       NaN
# 6      Low  4.4  free  Summer          o-neck   sleevless      NaN       NaN
# 7     high  4.3     M  Spring       boat-neck        full  natural  polyster
# 8  Average  4.8     M  winter  turndowncollor        full  natural       NaN
#
#             i
# 0         NaN
# 1         NaN
# 2     chiffon
# 3         NaN
# 4  broadcloth
# 5         NaN
# 6         NaN
# 7       terry
# 8         NaN

# %%
df
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
df.head()
# Out:
#      Dress_ID    Style    Price  Rating Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy      Low     4.6    M  Summer   o-neck    sleevless
# 1  1212192089   Casual      Low     0.0    L  Summer   o-neck        Petal
# 2  1190380701  vintage     High     0.0    L  Automn   o-neck         full
# 3   966005983    Brief  Average     4.6    L  Spring   o-neck         full
# 4   876339541     cute      Low     4.5    M  Summer   o-neck    butterfly
#
#   waiseline       Material FabricType  Decoration Pattern Type  Recommendation
# 0    empire            NaN    chiffon     ruffles       animal               1
# 1   natural     microfiber        NaN     ruffles       animal               0
# 2   natural       polyster        NaN         NaN        print               0
# 3   natural           silk    chiffon  embroidary        print               1
# 4   natural  chiffonfabric    chiffon         bow          dot               0

# %%
df.head(2)
# Out:
#      Dress_ID   Style Price  Rating Size  Season NeckLine SleeveLength  \
# 0  1006032852    Sexy   Low     4.6    M  Summer   o-neck    sleevless
# 1  1212192089  Casual   Low     0.0    L  Summer   o-neck        Petal
#
#   waiseline    Material FabricType Decoration Pattern Type  Recommendation
# 0    empire         NaN    chiffon    ruffles       animal               1
# 1   natural  microfiber        NaN    ruffles       animal               0

# %%
df.head(10)
# Out:
#      Dress_ID     Style    Price  Rating  Size  Season NeckLine SleeveLength  \
# 0  1006032852      Sexy      Low     4.6     M  Summer   o-neck    sleevless
# 1  1212192089    Casual      Low     0.0     L  Summer   o-neck        Petal
# 2  1190380701   vintage     High     0.0     L  Automn   o-neck         full
# 3   966005983     Brief  Average     4.6     L  Spring   o-neck         full
# 4   876339541      cute      Low     4.5     M  Summer   o-neck    butterfly
# 5  1068332458  bohemian      Low     0.0     M  Summer   v-neck    sleevless
# 6  1220707172    Casual  Average     0.0    XL  Summer   o-neck         full
# 7  1219677488   Novelty  Average     0.0  free  Automn   o-neck        short
# 8  1113094204     Flare  Average     0.0  free  Spring   v-neck        short
# 9   985292672  bohemian      Low     0.0  free  Summer   v-neck    sleevless
#
#   waiseline       Material  FabricType  Decoration Pattern Type  \
# ...

# %%
df.tail()
# Out:
#       Dress_ID   Style    Price  Rating  Size  Season   NeckLine SleeveLength  \
# 495  713391965  Casual      Low     4.7     M  Spring     o-neck         full
# 496  722565148    Sexy      Low     4.3  free  Summer     o-neck         full
# 497  532874347  Casual  Average     4.7     M  Summer     v-neck         full
# 498  655464934  Casual  Average     4.6     L  winter  boat-neck    sleevless
# 499  919930954  Casual      Low     4.4  free  Summer     v-neck        short
#
#     waiseline  Material  FabricType Decoration Pattern Type  Recommendation
# 495   natural  polyster         NaN        NaN        solid               1
# 496    empire    cotton         NaN        NaN          NaN               0
# 497    empire    cotton         NaN       lace        solid               1
# 498    empire      silk  broadcloth   applique        print               1
# 499    empire    cotton    Corduroy       lace        solid               0

# %%
df.tail(2)
# Out:
#       Dress_ID   Style    Price  Rating  Size  Season   NeckLine SleeveLength  \
# 498  655464934  Casual  Average     4.6     L  winter  boat-neck    sleevless
# 499  919930954  Casual      Low     4.4  free  Summer     v-neck        short
#
#     waiseline Material  FabricType Decoration Pattern Type  Recommendation
# 498    empire     silk  broadcloth   applique        print               1
# 499    empire   cotton    Corduroy       lace        solid               0

# %%
df.tail(10)
# Out:
#       Dress_ID     Style    Price  Rating  Size  Season   NeckLine  \
# 490  641665398    Casual      Low     4.8  free  winter    bowneck
# 491  964917582    Casual  Average     5.0     L  Summer     o-neck
# 492  859922576      cute  Average     4.6     M  Spring     o-neck
# 493  817353671  bohemian      Low     4.6  free  Summer     o-neck
# 494  990559192     Brief  Average     4.7     M  winter     o-neck
# 495  713391965    Casual      Low     4.7     M  Spring     o-neck
# 496  722565148      Sexy      Low     4.3  free  Summer     o-neck
# 497  532874347    Casual  Average     4.7     M  Summer     v-neck
# 498  655464934    Casual  Average     4.6     L  winter  boat-neck
# 499  919930954    Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline  Material  FabricType Decoration Pattern Type  \
# 490         full   natural  polyster     chiffon        bow        solid
# 491    sleevless   natural    cotton         NaN        NaN          NaN
# ...

# %%
pd.read_csv(r'C:\Users\SVKUSER\Downloads\haberman.csv')
# Out:
#      30  64   1  1.1
# 0    30  62   3    1
# 1    30  65   0    1
# 2    31  59   2    1
# 3    31  65   4    1
# 4    33  58  10    1
# ..   ..  ..  ..  ...
# 300  75  62   1    1
# 301  76  67   0    1
# 302  77  65   3    1
# 303  78  65   1    2
# 304  83  58   2    2
#
# [305 rows x 4 columns]

# %%
pd.read_csv(r'C:\Users\SVKUSER\Downloads\haberman.csv', header=None, names =["a","b","c","d"])
# Out:
#       a   b  c  d
# 0    30  64  1  1
# 1    30  62  3  1
# 2    30  65  0  1
# 3    31  59  2  1
# 4    31  65  4  1
# ..   ..  .. .. ..
# 301  75  62  1  1
# 302  76  67  0  1
# 303  77  65  3  1
# 304  78  65  1  2
# 305  83  58  2  2
#
# [306 rows x 4 columns]

# %%
pd.read_csv(r'C:\Users\SVKUSER\Downloads\haberman.csv', header=None, names =["Age","patient's year of operation", "number of operation"])
# Out:
#     Age  patient's year of operation  number of operation
# 30   64                            1                    1
# 30   62                            3                    1
# 30   65                            0                    1
# 31   59                            2                    1
# 31   65                            4                    1
# ..  ...                          ...                  ...
# 75   62                            1                    1
# 76   67                            0                    1
# 77   65                            3                    1
# 78   65                            1                    2
# 83   58                            2                    2
#
# [306 rows x 3 columns]

# %%
pd.read_csv(r'C:\Users\SVKUSER\Downloads\haberman1.csv')
# Out:
#       30@64@1@1
# 0     30@62@3@1
# 1     30@65@0@1
# 2     31@59@2@1
# 3     31@65@4@1
# 4    33@58@10@1
# ..          ...
# 300   75@62@1@1
# 301   76@67@0@1
# 302   77@65@3@1
# 303   78@65@1@2
# 304   83@58@2@2
#
# [305 rows x 1 columns]

# %%
pd.read_csv(r'C:\Users\SVKUSER\Downloads\haberman1.csv', sep = "@")
# Out:
#      30  64   1  1.1
# 0    30  62   3    1
# 1    30  65   0    1
# 2    31  59   2    1
# 3    31  65   4    1
# 4    33  58  10    1
# ..   ..  ..  ..  ...
# 300  75  62   1    1
# 301  76  67   0    1
# 302  77  65   3    1
# 303  78  65   1    2
# 304  83  58   2    2
#
# [305 rows x 4 columns]

# %%
pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Smarket.csv')
# Out:
#       Year   Lag1   Lag2   Lag3   Lag4   Lag5   Volume  Today Direction
# 0     2001  0.381 -0.192 -2.624 -1.055  5.010  1.19130  0.959        Up
# 1     2001  0.959  0.381 -0.192 -2.624 -1.055  1.29650  1.032        Up
# 2     2001  1.032  0.959  0.381 -0.192 -2.624  1.41120 -0.623      Down
# 3     2001 -0.623  1.032  0.959  0.381 -0.192  1.27600  0.614        Up
# 4     2001  0.614 -0.623  1.032  0.959  0.381  1.20570  0.213        Up
# ...    ...    ...    ...    ...    ...    ...      ...    ...       ...
# 1245  2005  0.422  0.252 -0.024 -0.584 -0.285  1.88850  0.043        Up
# 1246  2005  0.043  0.422  0.252 -0.024 -0.584  1.28581 -0.955      Down
# 1247  2005 -0.955  0.043  0.422  0.252 -0.024  1.54047  0.130        Up
# 1248  2005  0.130 -0.955  0.043  0.422  0.252  1.42236 -0.298      Down
# 1249  2005 -0.298  0.130 -0.955  0.043  0.422  1.38254 -0.489      Down
#
# [1250 rows x 9 columns]

# %%
pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Admission.csv')
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# ...

# %%
pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/College.csv')
# Out:
#     Private   Apps  Accept  Enroll  Top10perc  Top25perc  F.Undergrad  \
# 0       Yes   1660    1232     721         23         52         2885
# 1       Yes   2186    1924     512         16         29         2683
# 2       Yes   1428    1097     336         22         50         1036
# 3       Yes    417     349     137         60         89          510
# 4       Yes    193     146      55         16         44          249
# ..      ...    ...     ...     ...        ...        ...          ...
# 772      No   2197    1515     543          4         26         3089
# 773     Yes   1959    1805     695         24         47         2849
# 774     Yes   2097    1915     695         34         61         2793
# 775     Yes  10705    2453    1317         95         99         5217
# 776     Yes   2989    1855     691         28         63         2988
#
#      P.Undergrad  Outstate  Room.Board  Books  Personal  PhD  Terminal  \
# ...

# %%
a = pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')

# %%
a
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
type(a)
# Out:
# list

# %%
len(a)
# Out:
# 1

# %%
a[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
pd.read_json('https://api.github.com/repos/pandas-dev/pandas/issues')
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
js = pd.read_json('https://api.github.com/repos/pandas-dev/pandas/issues')

# %%
js.columns
# Out:
# Index(['url', 'repository_url', 'labels_url', 'comments_url', 'events_url',
#        'html_url', 'id', 'node_id', 'number', 'title', 'user', 'labels',
#        'state', 'locked', 'assignee', 'assignees', 'milestone', 'comments',
#        'created_at', 'updated_at', 'closed_at', 'author_association',
#        'active_lock_reason', 'body', 'reactions', 'timeline_url',
#        'performed_via_github_app', 'state_reason', 'draft', 'pull_request'],
#       dtype='object')

# %%
js['user']
# Out:
# 0     {'login': 'btodac', 'id': 45459748, 'node_id':...
# 1     {'login': 'jorisvandenbossche', 'id': 1020496,...
# 2     {'login': 'jorisvandenbossche', 'id': 1020496,...
# 3     {'login': 'datapythonista', 'id': 10058240, 'n...
# 4     {'login': 'shourya5', 'id': 73142986, 'node_id...
# 5     {'login': 'fangchenli', 'id': 7614606, 'node_i...
# 6     {'login': 'hawkinsp', 'id': 348932, 'node_id':...
# 7     {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 8     {'login': 'simonjayhawkins', 'id': 13159005, '...
# 9     {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 10    {'login': 'logankilpatrick', 'id': 35577566, '...
# 11    {'login': 'PMLP-novo', 'id': 54025656, 'node_i...
# 12    {'login': 'joshuabello2550', 'id': 43732414, '...
# 13    {'login': 'kapiliyer', 'id': 90269125, 'node_i...
# 14    {'login': 'twoertwein', 'id': 6618166, 'node_i...
# 15    {'login': 'ParfaitG', 'id': 13602663, 'node_id...
# 16    {'login': 'phofl', 'id': 61934744, 'node_id': ...
# ...

# %%
js['user'][0]
# Out:
# {'login': 'btodac',
#  'id': 45459748,
#  'node_id': 'MDQ6VXNlcjQ1NDU5NzQ4',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/45459748?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/btodac',
#  'html_url': 'https://github.com/btodac',
#  'followers_url': 'https://api.github.com/users/btodac/followers',
#  'following_url': 'https://api.github.com/users/btodac/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/btodac/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/btodac/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/btodac/subscriptions',
#  'organizations_url': 'https://api.github.com/users/btodac/orgs',
#  'repos_url': 'https://api.github.com/users/btodac/repos',
#  'events_url': 'https://api.github.com/users/btodac/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/btodac/received_events',
#  'type': 'User',
#  'site_admin': False}

# %%
js['user'][18]
# Out:
# {'login': 'phofl',
#  'id': 61934744,
#  'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/phofl',
#  'html_url': 'https://github.com/phofl',
#  'followers_url': 'https://api.github.com/users/phofl/followers',
#  'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#  'organizations_url': 'https://api.github.com/users/phofl/orgs',
#  'repos_url': 'https://api.github.com/users/phofl/repos',
#  'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/phofl/received_events',
#  'type': 'User',
#  'site_admin': False}

# %%
js['user'][20]
# Out:
# {'login': 'xr-chen',
#  'id': 56777910,
#  'node_id': 'MDQ6VXNlcjU2Nzc3OTEw',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/56777910?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/xr-chen',
#  'html_url': 'https://github.com/xr-chen',
#  'followers_url': 'https://api.github.com/users/xr-chen/followers',
#  'following_url': 'https://api.github.com/users/xr-chen/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/xr-chen/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/xr-chen/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/xr-chen/subscriptions',
#  'organizations_url': 'https://api.github.com/users/xr-chen/orgs',
#  'repos_url': 'https://api.github.com/users/xr-chen/repos',
#  'events_url': 'https://api.github.com/users/xr-chen/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/xr-chen/received_events',
#  'type': 'User',
#  'site_admin': False}

# %%
js['user'][6]
# Out:
# {'login': 'hawkinsp',
#  'id': 348932,
#  'node_id': 'MDQ6VXNlcjM0ODkzMg==',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/348932?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/hawkinsp',
#  'html_url': 'https://github.com/hawkinsp',
#  'followers_url': 'https://api.github.com/users/hawkinsp/followers',
#  'following_url': 'https://api.github.com/users/hawkinsp/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/hawkinsp/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/hawkinsp/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/hawkinsp/subscriptions',
#  'organizations_url': 'https://api.github.com/users/hawkinsp/orgs',
#  'repos_url': 'https://api.github.com/users/hawkinsp/repos',
#  'events_url': 'https://api.github.com/users/hawkinsp/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/hawkinsp/received_events',
#  'type': 'User',
#  'site_admin': False}

# %%
df = pd.read_excel(r'C:\Users\SVKUSER\Downloads\Attribute DataSet.xlxs.xlsx')

# %%
df
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
df.to_json('test123.json')

# %%
pwd
# Out:
# 'C:\\Users\\SVKUSER'

# %%
df
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
df.to_csv('E://test123.csv', sep = "@")

# %%
df.to_csv('E://test1234.csv', sep ="#", index =False)

# %%
Mysql:
    1.create a table for attributes dataset  and dress dataset
    2.do a bulk load for these two table for respective dataset
    3.read these dataset in pandas as a dataframe
    4.convert attribute dataset in json format
    5. store this dataset into mongodb
    6.in sql task try to perform left join operation with attribute dataset and dress dataset on coloum dress_id
    7.write a sql qure to find out how many unique dress that we have based on dress id
    8.Try to find out how many dress is having recommendation 0
    9.try to find out total dress sell for individual dress id
    10.try to find out a third highest most selling dress id
