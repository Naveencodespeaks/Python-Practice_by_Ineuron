# %%
import pandas as pd

# %%
df = pd.read_excel(r"C:\Users\SVKUSER\Downloads\Attribute DataSet (1).xlsx")

# %%
df
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
pd.read_excel(r'C:\Users\SVKUSER\Downloads\Attribute DataSet (1).xlsx', sheet_name="Sheet2")
# Out:
#     Average  4.5     M  Spring     v-neck         short   empire    cotton  \
# 0   Average  5.0  free  Spring     v-neck     sleevless  natural    cotton
# 1       Low  4.4     L  Automn     o-neck    halfsleeve  natural     rayon
# 2   Average  4.8     M  Winter     o-neck         short  natural     lycra
# 3       Low  4.8  free  Spring     o-neck     sleevless  natural    cotton
# 4   Average  4.8     M  Winter     o-neck     sleevless  natural    cotton
# 5   Average  0.0     M  Winter     o-neck         short  natural       NaN
# 6   Average  4.8     L  Spring     v-neck  threequarter   empire  polyster
# 7   Average  0.0     M  Summer     o-neck    halfsleeve  natural    cotton
# 8       Low  4.7     M  Summer     o-neck     sleevless   empire  milksilk
# 9    Medium  0.0     L  Winter  boat-neck          full   empire       NaN
# 10      Low  5.0  free  Summer     v-neck     sleevless   empire       NaN
# ...

# %%
pd.read_excel(r'C:\Users\SVKUSER\Downloads\Attribute DataSet (1).xlsx', sheet_name="Sheet3", header = None)
# Out:
#             0          1          2          3
# 0         NaN        NaN        NaN        NaN
# 1     Average     v-neck        NaN        NaN
# 2         Low     o-neck        NaN     v-neck
# 3     Average     o-neck        NaN     o-neck
# 4         Low  boat-neck        NaN     o-neck
# 5         NaN        NaN        NaN  boat-neck
# 6         NaN        NaN     v-neck        NaN
# 7      v-neck        NaN     o-neck        NaN
# 8      o-neck        NaN     o-neck        NaN
# 9      o-neck        NaN  boat-neck        NaN
# 10  boat-neck        NaN        NaN        NaN
# 11        NaN     v-neck        NaN        NaN
# 12        NaN     o-neck        NaN        NaN
# 13        NaN     o-neck        NaN        NaN
# 14        NaN  boat-neck        NaN        NaN

# %%
pd.read_excel(r'C:\Users\SVKUSER\Downloads\Attribute DataSet (1).xlsx', sheet_name="Sheet3", header = None)
# Out:
#             0          1          2          3
# 0         NaN        NaN        NaN        NaN
# 1     Average     v-neck        NaN        NaN
# 2         Low     o-neck        NaN     v-neck
# 3     Average     o-neck        NaN     o-neck
# 4         Low  boat-neck        NaN     o-neck
# 5         NaN        NaN        NaN  boat-neck
# 6         NaN        NaN     v-neck        NaN
# 7      v-neck        NaN     o-neck        NaN
# 8      o-neck        NaN     o-neck        NaN
# 9      o-neck        NaN  boat-neck        NaN
# 10  boat-neck        NaN        NaN        NaN
# 11        NaN     v-neck        NaN        NaN
# 12        NaN     o-neck        NaN        NaN
# 13        NaN     o-neck        NaN        NaN
# 14        NaN  boat-neck        NaN        NaN

# %%
pd.read_excel(r'C:\Users\SVKUSER\Downloads\Attribute DataSet (1).xlsx', sheet_name="Sheet3", header = None, names =['A','B','C'])
# Out:
#                    A          B          C
# NaN              NaN        NaN        NaN
# Average       v-neck        NaN        NaN
# Low           o-neck        NaN     v-neck
# Average       o-neck        NaN     o-neck
# Low        boat-neck        NaN     o-neck
# NaN              NaN        NaN  boat-neck
# NaN              NaN     v-neck        NaN
# v-neck           NaN     o-neck        NaN
# o-neck           NaN     o-neck        NaN
# o-neck           NaN  boat-neck        NaN
# boat-neck        NaN        NaN        NaN
# NaN           v-neck        NaN        NaN
# NaN           o-neck        NaN        NaN
# NaN           o-neck        NaN        NaN
# NaN        boat-neck        NaN        NaN

# %%
pd.read_excel(r"C:\Users\SVKUSER\Downloads\Attribute DataSet (1).xlsx")
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
df
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
df.head(2)
# Out:
#      Dress_ID   Style Price  Rating Size  Season NeckLine SleeveLength  \
# 0  1006032852    Sexy   Low     4.6    M  Summer   o-neck    sleevless
# 1  1212192089  Casual   Low     0.0    L  Summer   o-neck        Petal
#
#   waiseline    Material FabricType Decoration Pattern Type  Recommendation
# 0    empire         NaN    chiffon    ruffles       animal               1
# 1   natural  microfiber        NaN    ruffles       animal               0

# %%
df.head()
# Out:
#      Dress_ID    Style    Price  Rating Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy      Low     4.6    M  Summer   o-neck    sleevless
# 1  1212192089   Casual      Low     0.0    L  Summer   o-neck        Petal
# 2  1190380701  vintage     High     0.0    L  Automn   o-neck         full
# 3   966005983    Brief  Average     4.6    L  Spring   o-neck         full
# 4   876339541     cute      Low     4.5    M  Summer   o-neck    butterfly
#
#   waiseline       Material FabricType  Decoration Pattern Type  Recommendation
# 0    empire            NaN    chiffon     ruffles       animal               1
# 1   natural     microfiber        NaN     ruffles       animal               0
# 2   natural       polyster        NaN         NaN        print               0
# 3   natural           silk    chiffon  embroidary        print               1
# 4   natural  chiffonfabric    chiffon         bow          dot               0

# %%
df.tail()
# Out:
#       Dress_ID   Style    Price  Rating  Size  Season   NeckLine SleeveLength  \
# 495  713391965  Casual      Low     4.7     M  Spring     o-neck         full
# 496  722565148    Sexy      Low     4.3  free  Summer     o-neck         full
# 497  532874347  Casual  Average     4.7     M  Summer     v-neck         full
# 498  655464934  Casual  Average     4.6     L  winter  boat-neck    sleevless
# 499  919930954  Casual      Low     4.4  free  Summer     v-neck        short
#
#     waiseline  Material  FabricType Decoration Pattern Type  Recommendation
# 495   natural  polyster         NaN        NaN        solid               1
# 496    empire    cotton         NaN        NaN          NaN               0
# 497    empire    cotton         NaN       lace        solid               1
# 498    empire      silk  broadcloth   applique        print               1
# 499    empire    cotton    Corduroy       lace        solid               0

# %%
df.tail(2)
# Out:
#       Dress_ID   Style    Price  Rating  Size  Season   NeckLine SleeveLength  \
# 498  655464934  Casual  Average     4.6     L  winter  boat-neck    sleevless
# 499  919930954  Casual      Low     4.4  free  Summer     v-neck        short
#
#     waiseline Material  FabricType Decoration Pattern Type  Recommendation
# 498    empire     silk  broadcloth   applique        print               1
# 499    empire   cotton    Corduroy       lace        solid               0

# %%
pd.read_csv(r'C:\Users\SVKUSER\Downloads\haberman (2).csv', header = None, names =['Age', 'years',])
# Out:
#            Age  years
# 0    30@64@1@1    NaN
# 1    30@62@3@1    NaN
# 2    30@65@0@1    NaN
# 3    31@59@2@1    NaN
# 4    31@65@4@1    NaN
# ..         ...    ...
# 301  75@62@1@1    NaN
# 302  76@67@0@1    NaN
# 303  77@65@3@1    NaN
# 304  78@65@1@2    NaN
# 305  83@58@2@2    NaN
#
# [306 rows x 2 columns]

# %%
import pandas as pd

# %%
pd.read_excel(r"C:\Users\SVKUSER\Downloads\Attribute DataSet (1).xlsx")
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
pd.read_csv(r"C:\Users\SVKUSER\Downloads\haberman (2).csv", header = None, names =["A","B","c"])
# Out:
#              A   B   c
# 0    30@64@1@1 NaN NaN
# 1    30@62@3@1 NaN NaN
# 2    30@65@0@1 NaN NaN
# 3    31@59@2@1 NaN NaN
# 4    31@65@4@1 NaN NaN
# ..         ...  ..  ..
# 301  75@62@1@1 NaN NaN
# 302  76@67@0@1 NaN NaN
# 303  77@65@3@1 NaN NaN
# 304  78@65@1@2 NaN NaN
# 305  83@58@2@2 NaN NaN
#
# [306 rows x 3 columns]

# %%
pd.read_csv(r'C:\Users\SVKUSER\Downloads\haberman (2).csv', header = None, names =['Age', "patients's years"])
# Out:
#            Age  patients's years
# 0    30@64@1@1               NaN
# 1    30@62@3@1               NaN
# 2    30@65@0@1               NaN
# 3    31@59@2@1               NaN
# 4    31@65@4@1               NaN
# ..         ...               ...
# 301  75@62@1@1               NaN
# 302  76@67@0@1               NaN
# 303  77@65@3@1               NaN
# 304  78@65@1@2               NaN
# 305  83@58@2@2               NaN
#
# [306 rows x 2 columns]

# %%
pd.read_csv(r'C:\Users\SVKUSER\Downloads\haberman (2).csv', header = None, names =['Age', "patients's years","number of position", "Survival status"])
# Out:
#            Age  patients's years  number of position  Survival status
# 0    30@64@1@1               NaN                 NaN              NaN
# 1    30@62@3@1               NaN                 NaN              NaN
# 2    30@65@0@1               NaN                 NaN              NaN
# 3    31@59@2@1               NaN                 NaN              NaN
# 4    31@65@4@1               NaN                 NaN              NaN
# ..         ...               ...                 ...              ...
# 301  75@62@1@1               NaN                 NaN              NaN
# 302  76@67@0@1               NaN                 NaN              NaN
# 303  77@65@3@1               NaN                 NaN              NaN
# 304  78@65@1@2               NaN                 NaN              NaN
# 305  83@58@2@2               NaN                 NaN              NaN
#
# [306 rows x 4 columns]

# %%
pd.read_csv(r"C:\Users\SVKUSER\Downloads\haberman (2).csv")
# Out:
#       30@64@1@1
# 0     30@62@3@1
# 1     30@65@0@1
# 2     31@59@2@1
# 3     31@65@4@1
# 4    33@58@10@1
# ..          ...
# 300   75@62@1@1
# 301   76@67@0@1
# 302   77@65@3@1
# 303   78@65@1@2
# 304   83@58@2@2
#
# [305 rows x 1 columns]

# %%
pd.read_csv(r"C:\Users\SVKUSER\Downloads\haberman (2).csv", sep = "@")
# Out:
#      30  64   1  1.1
# 0    30  62   3    1
# 1    30  65   0    1
# 2    31  59   2    1
# 3    31  65   4    1
# 4    33  58  10    1
# ..   ..  ..  ..  ...
# 300  75  62   1    1
# 301  76  67   0    1
# 302  77  65   3    1
# 303  78  65   1    2
# 304  83  58   2    2
#
# [305 rows x 4 columns]

# %%
pd.read_csv("https://raw.githubusercontent.com/selva86/datasets/master/Smarket.csv")
# Out:
#       Year   Lag1   Lag2   Lag3   Lag4   Lag5   Volume  Today Direction
# 0     2001  0.381 -0.192 -2.624 -1.055  5.010  1.19130  0.959        Up
# 1     2001  0.959  0.381 -0.192 -2.624 -1.055  1.29650  1.032        Up
# 2     2001  1.032  0.959  0.381 -0.192 -2.624  1.41120 -0.623      Down
# 3     2001 -0.623  1.032  0.959  0.381 -0.192  1.27600  0.614        Up
# 4     2001  0.614 -0.623  1.032  0.959  0.381  1.20570  0.213        Up
# ...    ...    ...    ...    ...    ...    ...      ...    ...       ...
# 1245  2005  0.422  0.252 -0.024 -0.584 -0.285  1.88850  0.043        Up
# 1246  2005  0.043  0.422  0.252 -0.024 -0.584  1.28581 -0.955      Down
# 1247  2005 -0.955  0.043  0.422  0.252 -0.024  1.54047  0.130        Up
# 1248  2005  0.130 -0.955  0.043  0.422  0.252  1.42236 -0.298      Down
# 1249  2005 -0.298  0.130 -0.955  0.043  0.422  1.38254 -0.489      Down
#
# [1250 rows x 9 columns]

# %%
pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_totals.html")
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
a = pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_totals.html")

# %%
type(a)
# Out:
# list

# %%
a[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
len(a)
# Out:
# 1

# %%
a[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
pd.read_json("https://api.github.com/repos/pandas-dev/pandas/issues")
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
js = pd.read_json("https://api.github.com/repos/pandas-dev/pandas/issues")

# %%
js
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
js.columns
# Out:
# Index(['url', 'repository_url', 'labels_url', 'comments_url', 'events_url',
#        'html_url', 'id', 'node_id', 'number', 'title', 'user', 'labels',
#        'state', 'locked', 'assignee', 'assignees', 'milestone', 'comments',
#        'created_at', 'updated_at', 'closed_at', 'author_association',
#        'active_lock_reason', 'body', 'reactions', 'timeline_url',
#        'performed_via_github_app', 'state_reason', 'draft', 'pull_request'],
#       dtype='object')

# %%
js['user']
# Out:
# 0     {'login': 'gwerbin', 'id': 5758789, 'node_id':...
# 1     {'login': 'yuanx749', 'id': 47032563, 'node_id...
# 2     {'login': 'ssche', 'id': 7367411, 'node_id': '...
# 3     {'login': 'maartenb', 'id': 808867, 'node_id':...
# 4     {'login': 'twoertwein', 'id': 6618166, 'node_i...
# 5     {'login': 'dxdc', 'id': 7200365, 'node_id': 'M...
# 6     {'login': 'rhshadrach', 'id': 45562402, 'node_...
# 7     {'login': 'phofl', 'id': 61934744, 'node_id': ...
# 8     {'login': 'lukemanley', 'id': 8519523, 'node_i...
# 9     {'login': 'alexc-yellowcanary', 'id': 11079634...
# 10    {'login': 'jonashaag', 'id': 175722, 'node_id'...
# 11    {'login': 'rhshadrach', 'id': 45562402, 'node_...
# 12    {'login': 'un000', 'id': 19488486, 'node_id': ...
# 13    {'login': 'phofl', 'id': 61934744, 'node_id': ...
# 14    {'login': 'ambujpawar', 'id': 19887541, 'node_...
# 15    {'login': 'phofl', 'id': 61934744, 'node_id': ...
# 16    {'login': 'lukemanley', 'id': 8519523, 'node_i...
# ...

# %%
js['user'][0]
# Out:
# {'login': 'gwerbin',
#  'id': 5758789,
#  'node_id': 'MDQ6VXNlcjU3NTg3ODk=',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/5758789?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/gwerbin',
#  'html_url': 'https://github.com/gwerbin',
#  'followers_url': 'https://api.github.com/users/gwerbin/followers',
#  'following_url': 'https://api.github.com/users/gwerbin/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/gwerbin/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/gwerbin/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/gwerbin/subscriptions',
#  'organizations_url': 'https://api.github.com/users/gwerbin/orgs',
#  'repos_url': 'https://api.github.com/users/gwerbin/repos',
#  'events_url': 'https://api.github.com/users/gwerbin/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/gwerbin/received_events',
#  'type': 'User',
#  'site_admin': False}

# %%
df= pd.read_excel(r"C:\Users\SVKUSER\Downloads\Attribute DataSet (1).xlsx")

# %%
df
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
df.to_json("babblu.json")

# %%
pwd
# Out:
# 'C:\\Users\\SVKUSER'

# %%
df.to_csv("E://babblu.csv")

# %%
pwd
# Out:
# 'C:\\Users\\SVKUSER'

# %%
df.to_csv("E://babblu.csv",sep = "#")

# %%
df.to_csv("E://babblu123.csv",sep = "#", index = False)
